# %% [markdown]
# # Main notebook for data processing in robo_romeo project

# %% [markdown]
# ## Imports - this should do us for the whole project.

# %%
import numpy as np
from PIL import Image
import os
import string
from pickle import dump
from pickle import load
import tensorflow as tf
from tensorflow.keras.applications.xception import Xception #to get pre-trained model Xception
from tensorflow.keras.applications.xception import preprocess_input
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.text import Tokenizer #for text tokenization
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import add
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense#Keras to build our CNN and LSTM
from tensorflow.keras.layers import LSTM, Embedding, Dropout
from tqdm import tqdm_notebook as tqdm #to check loop progress
# Out:
# /var/folders/tw/_zhlxthd7c31pn2_v_8xnv3m0000gn/T/ipykernel_25854/3341886489.py:20: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   tqdm().pandas()
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [1], in <cell line: 20>()
#      18 from tensorflow.keras.layers import LSTM, Embedding, Dropout
#      19 from tqdm import tqdm_notebook as tqdm #to check loop progress
# ---> 20 tqdm().pandas()
#
# File ~/.pyenv/versions/3.8.12/envs/robo_romeo/lib/python3.8/site-packages/tqdm/__init__.py:28, in tqdm_notebook(*args, **kwargs)
#      24 from .notebook import tqdm as _tqdm_notebook
#      25 warn("This function will be removed in tqdm==5.0.0\n"
#      26      "Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`",
#      27      TqdmDeprecationWarning, stacklevel=2)
# ---> 28 return _tqdm_notebook(*args, **kwargs)
#
# File ~/.pyenv/versions/3.8.12/envs/robo_romeo/lib/python3.8/site-packages/tqdm/notebook.py:242, in tqdm_notebook.__init__(self, *args, **kwargs)
#     240 unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     241 total = self.total * unit_scale if self.total else self.total
# --> 242 self.container = self.status_printer(self.fp, total, self.desc, self.ncols)
#     243 self.container.pbar = proxy(self)
#     244 self.displayed = False
#
# File ~/.pyenv/versions/3.8.12/envs/robo_romeo/lib/python3.8/site-packages/tqdm/notebook.py:118, in tqdm_notebook.status_printer(_, total, desc, ncols)
#     109 # Fallback to text bar if there's no total
#     110 # DEPRECATED: replaced with an 'info' style bar
#     111 # if not total:
#    (...)
#     115
#     116 # Prepare IPython progress bar
#     117 if IProgress is None:  # #187 #451 #558 #872
# --> 118     raise ImportError(WARN_NOIPYW)
#     119 if total:
#     120     pbar = IProgress(min=0, max=total)
#
# ImportError: IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %% [markdown]
# ## Data cleaning

# %% [markdown]
#  - load_doc( filename ) – To load the document file and read the contents of the file into a string.

# %%
# Load the document file into memory
def load_doc(filename):
    # Open file to read
    file = open(filename, 'r')
    text = file.read()
    file.close()
    return text

# %%
filename = '../raw_data/text/Flickr8k.token.txt'
# load descriptions
doc = load_doc(filename)

# %% [markdown]
#  - load_descriptions(doc) – To create a description dictionary that will map images with all 5 captions.

# %%
# extract descriptions for images
def load_descriptions(doc):
    mapping = dict()
    # process lines
    for line in doc.split('\n'):
        # split line by white space
        tokens = line.split()
        if len(line) < 2:
            continue
        # take the first token as the image id, the rest as the description
        image_id, image_desc = tokens[0], tokens[1:]
        # remove filename from image id
        image_id = image_id.split('.')[0]
        # convert description tokens back to string
        image_desc = ' '.join(image_desc)
        # create the list if needed
        if image_id not in mapping:
            mapping[image_id] = list()
        # store description
        mapping[image_id].append(image_desc)
    return mapping

# %%
# parse descriptions
descriptions = load_descriptions(doc)
print('Loaded: %d ' % len(descriptions))
# Out:
# Loaded: 8092

# %% [markdown]
#  - clean_descriptions( descriptions) – to clean the data by taking all descriptions as input. This will perform several types of cleaning including uppercase to lowercase conversion, punctuation removal, and removal of the number containing words.

# %%
import string

# %%
def clean_descriptions(descriptions):
    # prepare translation table for removing punctuation
    table = str.maketrans('', '', string.punctuation)
    for key, desc_list in descriptions.items():
        for i in range(len(desc_list)):
            desc = desc_list[i]
            # tokenize
            desc = desc.split()
            # convert to lower case
            desc = [word.lower() for word in desc]
            # remove punctuation from each token
            desc = [w.translate(table) for w in desc]
            # remove tokens with numbers in them
            desc = [word for word in desc if word.isalpha()]
            # store as string
            desc_list[i] =  ' '.join(desc)

# %%
# clean descriptions
clean_descriptions(descriptions)

# %% [markdown]
#  - txt_vocab( descriptions ) – to create a vocabulary from all the unique words extracted out from descriptions.

# %%
# convert the loaded descriptions into a vocabulary of words
def to_vocabulary(descriptions):
    # build a list of all description strings
    all_desc = set()
    for key in descriptions.keys():
        [all_desc.update(d.split()) for d in descriptions[key]]
    return all_desc

# %%
# summarize vocabulary
vocabulary = to_vocabulary(descriptions)
print('Vocabulary Size: %d' % len(vocabulary))
# Out:
# Vocabulary Size: 8763

# %% [markdown]
#  - save_descriptions( descriptions, filename ) – This function is used to store all the preprocessed descriptions into a file.

# %%
# !pwd
# Out:
# /Users/theebak/code/theebak31/robo_romeo/notebooks

# %%
# save descriptions to file, one per line
def save_descriptions(descriptions, filename):
    lines = list()
    for key, desc_list in descriptions.items():
        for desc in desc_list:
            lines.append(key + ' ' + desc)
    data = '\n'.join(lines)
    file = open(filename, 'w')
    file.write(data)
    file.close()

# %%
# save descriptions
save_descriptions(descriptions, 'descriptions.txt')

# %%
# !pwd
# Out:
# /Users/theebak/code/theebak31/robo_romeo/notebooks

# %%
filename = '../raw_data/text/Flickr8k.token.txt'
# load descriptions
doc = load_doc(filename)
# parse descriptions
descriptions = load_descriptions(doc)
print('Loaded: %d ' % len(descriptions))
# clean descriptions
clean_descriptions(descriptions)
# summarize vocabulary
vocabulary = to_vocabulary(descriptions)
print('Vocabulary Size: %d' % len(vocabulary))
# save to file
save_descriptions(descriptions, 'descriptions.txt')
# Out:
# Loaded: 8092
# Vocabulary Size: 8763

# %%
def sequencing(file):
    
    with open(file) as f:
        lines = f.readlines()
    #splitting the lines in to lists
    
    list = []
    training_list = []
    X1 = []
    X2 = []
    y = []
    token_vocab = []
    
    k_file = "../raw_data/text/Flickr_8k.trainImages.txt"

    with open(k_file) as n:
        l = n.readlines()
    for line in l:
        training_list.append(line.replace(".jpg\n", ""))
    
    for j in lines:
        list.append(j.split())
    
    for item in list:
        item.insert(1,"startsequence")
        item.append("endsequence")
        token_vocab.append(' '.join(item[1:]))
        
    
    # for loop to append X1,X2,y

    
    for i in list:
        for seq in range(2,len(i)):
            if i[0] in training_list:
                X1.append(i[0])
                X2.append(' '.join(i[1:seq]))
                y.append(i[seq])
            else:
                pass


    return(X1,X2,y,token_vocab)

# %%
X1,X2,y,token_vocab = sequencing('descriptions.txt')

# %%
len(set(y))
# Out:
# 7577

# %%
token_vocab[0]
# Out:
# ['startsequence',
#  'a',
#  'child',
#  'in',
#  'a',
#  'pink',
#  'dress',
#  'is',
#  'climbing',
#  'up',
#  'a',
#  'set',
#  'of',
#  'stairs',
#  'in',
#  'an',
#  'entry',
#  'way',
#  'endsequence']

# %%
#Tokenizing X2
t = Tokenizer()
t.fit_on_texts(token_vocab)
X2_tokenized = t.texts_to_sequences(X2)

#Tokenizing y
y_tokenized = np.array(t.texts_to_sequences(y))

# %%
y_tokenized[14]
# Out:
# array([28])

# %%
y_vocab = len(t.word_index.keys())
y_vocab
# Out:
# 8777

# %%
y_tokenized.shape
# Out:
# (353505, 1)

# %%
y = to_categorical(y_tokenized, num_classes=y_vocab+1)

# %%
X2_tokenized
# Out:
# [[2],
#  [2, 1],
#  [2, 1, 42],
#  [2, 1, 42, 4],
#  [2, 1, 42, 4, 1],
#  [2, 1, 42, 4, 1, 90],
#  [2, 1, 42, 4, 1, 90, 170],
#  [2, 1, 42, 4, 1, 90, 170, 7],
#  [2, 1, 42, 4, 1, 90, 170, 7, 119],
#  [2, 1, 42, 4, 1, 90, 170, 7, 119, 53],
#  [2, 1, 42, 4, 1, 90, 170, 7, 119, 53, 1],
#  [2, 1, 42, 4, 1, 90, 170, 7, 119, 53, 1, 396],
#  [2, 1, 42, 4, 1, 90, 170, 7, 119, 53, 1, 396, 12],
#  [2, 1, 42, 4, 1, 90, 170, 7, 119, 53, 1, 396, 12, 393],
#  [2, 1, 42, 4, 1, 90, 170, 7, 119, 53, 1, 396, 12, 393, 4],
#  [2, 1, 42, 4, 1, 90, 170, 7, 119, 53, 1, 396, 12, 393, 4, 28],
#  [2, 1, 42, 4, 1, 90, 170, 7, 119, 53, 1, 396, 12, 393, 4, 28, 5199],
#  [2, 1, 42, 4, 1, 90, 170, 7, 119, 53, 1, 396, 12, 393, 4, 28, 5199, 693],
#  [2],
#  [2, 1],
#  [2, 1, 19],
#  [2, 1, 19, 314],
#  [2, 1, 19, 314, 64],
#  [2, 1, 19, 314, 64, 1],
#  [2, 1, 19, 314, 64, 1, 194],
#  [2, 1, 19, 314, 64, 1, 194, 117],
#  [2],
#  [2, 1],
#  [2, 1, 40],
#  [2, 1, 40, 19],
#  [2, 1, 40, 19, 119],
#  [2, 1, 40, 19, 119, 64],
#  [2, 1, 40, 19, 119, 64, 1],
#  [2, 1, 40, 19, 119, 64, 1, 194],
#  [2, 1, 40, 19, 119, 64, 1, 194, 2425],
#  [2],
#  [2, 1],
#  [2, 1, 40],
#  [2, 1, 40, 19],
#  [2, 1, 40, 19, 119],
#  [2, 1, 40, 19, 119, 5],
#  [2, 1, 40, 19, 119, 5, 393],
#  [2, 1, 40, 19, 7, 49, 4, 47, 12, 1, 55],
#  [2, 1, 40, 19, 7, 49, 4, 47, 12, 1, 55, 596],
#  [2, 1, 40, 19, 7, 49, 4, 47, 12, 1, 55, 596, 1184],
#  [2],
#  [2, 1],
#  [2, 1, 52],
#  [2, 1, 52, 19],
#  [2, 1, 52, 19, 4],
#  [2, 1, 52, 19, 4, 5],
#  [2, 1, 52, 19, 4, 5, 41],
#  [2, 1, 52, 19, 4, 5, 41, 114],
#  [2, 1, 52, 19, 4, 5, 41, 114, 10],
#  [2, 1, 52, 19, 4, 5, 41, 114, 10, 3430],
#  [2, 1, 52, 19, 4, 5, 41, 114, 10, 3430, 4],
#  [2, 1, 52, 19, 4, 5, 41, 114, 10, 3430, 4, 47],
#  [2, 1, 52, 19, 4, 5, 41, 114, 10, 3430, 4, 47, 12],
#  [2, 1, 52, 19, 4, 5, 41, 114, 10, 3430, 4, 47, 12, 1],
#  [2, 1, 52, 19, 4, 5, 41, 114, 10, 3430, 4, 47, 12, 1, 14],
#  [2, 1, 52, 19, 4, 5, 41, 114, 10, 3430, 4, 47, 12, 1, 14, 2426],
#  [2, 1, 52, 19, 4, 5, 41, 114, 10, 3430, 4, 47, 12, 1, 14, 2426, 10],
#  [2, 1, 52, 19, 4, 5, 41, 114, 10, 3430, 4, 47, 12, 1, 14, 2426, 10, 1],
#  [2, 1, 52, 19, 4, 5, 41, 114, 10, 3430, 4, 47, 12, 1, 14, 2426, 10, 1, 1184],
#  [2,
#   1,
#   52,
#   19,
#   4,
#   5,
#   41,
#   114,
#   10,
#   3430,
#   4,
#   47,
#   12,
#   1,
#   14,
#   2426,
#   10,
#   1,
#   1184,
#   6],
#  [2,
#   1,
#   52,
#   19,
#   4,
#   5,
#   41,
#   114,
#   10,
#   3430,
#   4,
#   47,
#   12,
#   1,
#   14,
#   2426,
#   10,
#   1,
#   1184,
#   6,
#   149],
#  [2],
#  [2, 187],
#  [2, 187, 7],
#  [2, 187, 7, 1],
#  [2, 187, 7, 1, 19],
#  [2, 187, 7, 1, 19, 10],
#  [2, 187, 7, 1, 19, 10, 1558],
#  [2, 187, 7, 1, 19, 10, 1558, 49],
#  [2, 187, 7, 1, 19, 10, 1558, 49, 4],
#  [2, 187, 7, 1, 19, 10, 1558, 49, 4, 47],
#  [2, 187, 7, 1, 19, 10, 1558, 49, 4, 47, 12],
#  [2, 187, 7, 1, 19, 10, 1558, 49, 4, 47, 12, 1],
#  [2, 187, 7, 1, 19, 10, 1558, 49, 4, 47, 12, 1, 1184],
#  [2, 187, 7, 1, 19, 10, 1558, 49, 4, 47, 12, 1, 1184, 766],
#  [2],
#  [2, 26],
#  [2, 26, 19],
#  [2, 26, 19, 10],
#  [2, 26, 19, 10, 1558],
#  [2, 26, 19, 10, 1558, 766],
#  [2, 26, 19, 10, 1558, 766, 81],
#  [2, 26, 19, 10, 1558, 766, 81, 4],
#  [2, 26, 19, 10, 1558, 766, 81, 4, 5],
#  [2, 1, 26, 42, 7, 61, 6, 1, 354, 768, 72],
#  [2, 1, 26, 42, 7, 61, 6, 1, 354, 768, 72, 10],
#  [2, 1, 26, 42, 7, 61, 6, 1, 354, 768, 72, 10, 1],
#  [2, 1, 26, 42, 7, 61, 6, 1, 354, 768, 72, 10, 1, 382],
#  [2, 1, 26, 42, 7, 61, 6, 1, 354, 768, 72, 10, 1, 382, 302],
#  [2, 1, 26, 42, 7, 61, 6, 1, 354, 768, 72, 10, 1, 382, 302, 8],
#  [2, 1, 26, 42, 7, 61, 6, 1, 354, 768, 72, 10, 1, 382, 302, 8, 1],
#  [2, 1, 26, 42, 7, 61, 6, 1, 354, 768, 72, 10, 1, 382, 302, 8, 1, 11],
#  [2, 1, 26, 42, 7, 61, 6, 1, 354, 768, 72, 10, 1, 382, 302, 8, 1, 11, 100],
#  [2,
#   1,
#   26,
#   42,
#   7,
#   61,
#   6,
#   1,
#   354,
#   768,
#   72,
#   10,
#   1,
#   382,
#   302,
#   8,
#   1,
#   11,
#   100,
#   147],
#  [2],
#  [2, 129],
#  [2, 129, 16],
#  [2, 129, 16, 4],
#  [2, 129, 16, 4, 14],
#  [2, 129, 16, 4, 14, 37],
#  [2, 129, 16, 4, 14, 37, 8],
#  [2, 129, 16, 4, 14, 37, 8, 30],
#  [2, 129, 16, 4, 14, 37, 8, 30, 232],
#  [2, 129, 16, 4, 14, 37, 8, 30, 232, 4],
#  [2, 129, 16, 4, 14, 37, 8, 30, 232, 4, 47],
#  [2, 129, 16, 4, 14, 37, 8, 30, 232, 4, 47, 12],
#  [2, 129, 16, 4, 14, 37, 8, 30, 232, 4, 47, 12, 84],
#  [2, 129, 16, 4, 14, 37, 8, 30, 232, 4, 47, 12, 84, 109],
#  [2, 129, 16, 4, 14, 37, 8, 30, 232, 4, 47, 12, 84, 109, 10],
#  [2, 129, 16, 4, 14, 37, 8, 30, 232, 4, 47, 12, 84, 109, 10, 11],
#  [2, 129, 16, 4, 14, 37, 8, 30, 232, 4, 47, 12, 84, 109, 10, 11, 4],
#  [2, 129, 16, 4, 14, 37, 8, 30, 232, 4, 47, 12, 84, 109, 10, 11, 4, 1102],
#  [2, 129, 16, 4, 14, 37, 8, 30, 232, 4, 47, 12, 84, 109, 10, 11, 4, 1102, 100],
#  [2,
#   129,
#   16,
#   4,
#   14,
#   37,
#   8,
#   30,
#   232,
#   4,
#   47,
#   12,
#   84,
#   109,
#   10,
#   11,
#   4,
#   1102,
#   100,
#   147],
#  [2],
#  [2, 1],
#  [2, 1, 15],
#  [2, 1, 15, 9],
#  [2, 1, 15, 9, 246],
#  [2, 1, 15, 9, 246, 46],
#  [2, 1, 15, 9, 246, 46, 1],
#  [2, 1, 15, 9, 246, 46, 1, 652],
#  [2],
#  [2, 1],
#  [2, 1, 215],
#  [2, 1, 215, 9],
#  [2, 1, 215, 9, 7],
#  [2, 1, 215, 9, 7, 334],
#  [2, 1, 215, 9, 7, 334, 46],
#  [2, 1, 215, 9, 7, 334, 46, 1],
#  [2, 954, 1043, 17, 2111, 1, 84],
#  [2, 954, 1043, 17, 2111, 1, 84, 123],
#  [2, 954, 1043, 17, 2111, 1, 84, 123, 312],
#  [2, 954, 1043, 17, 2111, 1, 84, 123, 312, 70],
#  [2, 954, 1043, 17, 2111, 1, 84, 123, 312, 70, 11],
#  [2, 954, 1043, 17, 2111, 1, 84, 123, 312, 70, 11, 77],
#  [2, 954, 1043, 17, 2111, 1, 84, 123, 312, 70, 11, 77, 50],
#  [2, 954, 1043, 17, 2111, 1, 84, 123, 312, 70, 11, 77, 50, 5],
#  [2, 954, 1043, 17, 2111, 1, 84, 123, 312, 70, 11, 77, 50, 5, 212],
#  [2],
#  [2, 184],
#  [2, 184, 1043],
#  [2, 184, 1043, 4],
#  [2, 184, 1043, 4, 1],
#  [2, 184, 1043, 4, 1, 907],
#  [2, 184, 1043, 4, 1, 907, 17],
#  [2, 184, 1043, 4, 1, 907, 17, 119],
#  [2, 184, 1043, 4, 1, 907, 17, 119, 5],
#  [2, 184, 1043, 4, 1, 907, 17, 119, 5, 84],
#  [2, 184, 1043, 4, 1, 907, 17, 119, 5, 84, 35],
#  [2, 184, 1043, 4, 1, 907, 17, 119, 5, 84, 35, 5],
#  [2, 184, 1043, 4, 1, 907, 17, 119, 5, 84, 35, 5, 11],
#  [2, 184, 1043, 4, 1, 907, 17, 119, 5, 84, 35, 5, 11, 4],
#  [2, 184, 1043, 4, 1, 907, 17, 119, 5, 84, 35, 5, 11, 4, 25],
#  [2, 184, 1043, 4, 1, 907, 17, 119, 5, 84, 35, 5, 11, 4, 25, 199],
#  [2, 184, 1043, 4, 1, 907, 17, 119, 5, 84, 35, 5, 11, 4, 25, 199, 8],
#  [2, 184, 1043, 4, 1, 907, 17, 119, 5, 84, 35, 5, 11, 4, 25, 199, 8, 126],
#  [2, 184, 1043, 4, 1, 907, 17, 119, 5, 84, 35, 5, 11, 4, 25, 199, 8, 126, 5],
#  [2,
#   184,
#   1043,
#   4,
#   1,
#   907,
#   17,
#   119,
#   5,
#   84,
#   35,
#   5,
#   11,
#   4,
#   25,
#   199,
#   8,
#   126,
#   5,
#   317],
#  [2],
#  [2, 1],
#  [2, 1, 27],
#  [2, 1, 27, 9],
#  [2, 1, 27, 9, 422],
#  [2, 1, 27, 9, 422, 5],
#  [2, 1, 27, 9, 422, 5, 24],
#  [2, 1, 27, 9, 422, 5, 24, 75],
#  [2, 1, 27, 9, 422, 5, 24, 75, 1],
#  [2, 1, 27, 9, 422, 5, 24, 75, 1, 663],
#  [2, 1, 27, 9, 422, 5, 24, 75, 1, 663, 6],
#  [2, 1, 27, 9, 422, 5, 24, 75, 1, 663, 6, 1],
#  [2, 1, 27, 9, 422, 5, 24, 75, 1, 663, 6, 1, 372],
#  [2],
#  [2, 1],
#  [2, 1, 27],
#  [2, 1, 27, 9],
#  [2, 1, 27, 9, 114],
#  [2, 1, 27, 9, 114, 10],
#  [2, 1, 27, 9, 114, 10, 5],
#  [2, 1, 27, 9, 114, 10, 5, 740],
#  [2],
#  [2, 1],
#  [2, 1, 27],
#  [2, 1, 27, 9],
#  [2, 1, 27, 9, 32],
#  [2, 1, 27, 9, 32, 6],
#  [2, 1, 27, 9, 32, 6, 1],
#  [2, 1, 27, 9, 32, 6, 1, 372],
#  [2, 1, 27, 9, 32, 6, 1, 372, 67],
#  [2, 1, 27, 9, 32, 6, 1, 372, 67, 1],
#  [2, 1, 27, 9, 32, 6, 1, 372, 67, 1, 661],
#  [2, 1, 27, 9, 32, 6, 1, 372, 67, 1, 661, 740],
#  [2],
#  [2, 1],
#  [2, 1, 9],
#  [2, 1, 9, 7],
#  [2, 1, 9, 7, 34],
#  [2, 1, 9, 7, 34, 10],
#  [2, 1, 9, 7, 34, 10, 1],
#  [2, 1, 9, 7, 34, 10, 1, 740],
#  [2],
#  [2, 55],
#  [2, 55, 27],
#  [2, 55, 27, 9],
#  [2, 55, 27, 9, 32],
#  [2, 55, 27, 9, 32, 288],
#  [2, 55, 27, 9, 32, 288, 75],
#  [2, 55, 27, 9, 32, 288, 75, 5],
#  [2, 55, 27, 9, 32, 288, 75, 5, 663],
#  [2, 55, 27, 9, 32, 288, 75, 5, 663, 4],
#  [2, 55, 27, 9, 32, 288, 75, 5, 663, 4, 5],
#  [2, 55, 27, 9, 32, 288, 75, 5, 663, 4, 5, 41],
#  [2],
#  [2, 1],
#  [2, 1, 9],
#  [2, 1, 9, 694],
#  [2, 1, 9, 694, 20],
#  [2, 1, 9, 694, 20, 164],
#  [2, 1, 9, 694, 20, 164, 1],
#  [2, 1, 9, 694, 20, 164, 1, 741],
#  [2, 1, 9, 694, 20, 164, 1, 741, 305],
#  [2, 1, 9, 694, 20, 164, 1, 741, 305, 4],
#  [2, 1, 9, 694, 20, 164, 1, 741, 305, 4, 1],
#  [2, 1, 9, 694, 20, 164, 1, 741, 305, 4, 1, 51],
#  [2, 1, 9, 694, 20, 164, 1, 741, 305, 4, 1, 51, 10],
#  [2, 1, 9, 694, 20, 164, 1, 741, 305, 4, 1, 51, 10, 308],
#  [2, 1, 9, 694, 20, 164, 1, 741, 305, 4, 1, 51, 10, 308, 583],
#  [2],
#  [2, 1],
#  [2, 1, 14],
#  [2, 1, 14, 9],
#  [2, 1, 14, 9, 7],
#  [2, 1, 14, 9, 7, 313],
#  [2, 1, 14, 9, 7, 313, 20],
#  [2, 1, 14, 9, 7, 313, 20, 164],
#  [2, 1, 14, 9, 7, 313, 20, 164, 1],
#  [2, 1, 14, 9, 7, 313, 20, 164, 1, 59],
#  [2, 1, 14, 9, 7, 313, 20, 164, 1, 59, 39],
#  [2, 1, 14, 9, 7, 313, 20, 164, 1, 59, 39, 4],
#  [2, 1, 14, 9, 7, 313, 20, 164, 1, 59, 39, 4, 74],
#  [2, 1, 14, 9, 7, 313, 20, 164, 1, 59, 39, 4, 74, 68],
#  [2],
#  [2, 1],
#  [2, 1, 14],
#  [2, 1, 14, 9],
#  [2, 1, 14, 9, 7],
#  [2, 1, 14, 9, 7, 313],
#  [2, 1, 9, 246, 20, 164, 1, 39, 4],
#  [2, 1, 9, 246, 20, 164, 1, 39, 4, 1],
#  [2, 1, 9, 246, 20, 164, 1, 39, 4, 1, 51],
#  [2],
#  [2, 1],
#  [2, 1, 14],
#  [2, 1, 14, 9],
#  [2, 1, 14, 9, 7],
#  [2, 1, 14, 9, 7, 292],
#  ...]

# %%
#padding
X2_pad = pad_sequences(X2_tokenized, dtype='int32', padding='post', value=0)

# %%
f = X1,X2_pad,y

# %%
y.shape
# Out:
# (353505, 8778)

# %%
t.index_word
# Out:
# {1: 'a',
#  2: 'startsequence',
#  3: 'endsequence',
#  4: 'in',
#  5: 'the',
#  6: 'on',
#  7: 'is',
#  8: 'and',
#  9: 'dog',
#  10: 'with',
#  11: 'man',
#  12: 'of',
#  13: 'two',
#  14: 'white',
#  15: 'black',
#  16: 'boy',
#  17: 'are',
#  18: 'woman',
#  19: 'girl',
#  20: 'to',
#  21: 'wearing',
#  22: 'at',
#  23: 'people',
#  24: 'water',
#  25: 'red',
#  26: 'young',
#  27: 'brown',
#  28: 'an',
#  29: 'his',
#  30: 'blue',
#  31: 'dogs',
#  32: 'running',
#  33: 'through',
#  34: 'playing',
#  35: 'while',
#  36: 'down',
#  37: 'shirt',
#  38: 'standing',
#  39: 'ball',
#  40: 'little',
#  41: 'grass',
#  42: 'child',
#  43: 'person',
#  44: 'snow',
#  45: 'jumping',
#  46: 'over',
#  47: 'front',
#  48: 'three',
#  49: 'sitting',
#  50: 'holding',
#  51: 'field',
#  52: 'small',
#  53: 'up',
#  54: 'by',
#  55: 'large',
#  56: 'green',
#  57: 'one',
#  58: 'group',
#  59: 'yellow',
#  60: 'her',
#  61: 'walking',
#  62: 'children',
#  63: 'men',
#  64: 'into',
#  65: 'air',
#  66: 'beach',
#  67: 'near',
#  68: 'mouth',
#  69: 'jumps',
#  70: 'another',
#  71: 'for',
#  72: 'street',
#  73: 'runs',
#  74: 'its',
#  75: 'from',
#  76: 'riding',
#  77: 'stands',
#  78: 'as',
#  79: 'bike',
#  80: 'girls',
#  81: 'outside',
#  82: 'other',
#  83: 'out',
#  84: 'rock',
#  85: 'next',
#  86: 'play',
#  87: 'off',
#  88: 'looking',
#  89: 'orange',
#  90: 'pink',
#  91: 'player',
#  92: 'their',
#  93: 'camera',
#  94: 'pool',
#  95: 'hat',
#  96: 'jacket',
#  97: 'boys',
#  98: 'women',
#  99: 'around',
#  100: 'behind',
#  101: 'some',
#  102: 'background',
#  103: 'dirt',
#  104: 'toy',
#  105: 'soccer',
#  106: 'sits',
#  107: 'dressed',
#  108: 'has',
#  109: 'wall',
#  110: 'mountain',
#  111: 'walks',
#  112: 'crowd',
#  113: 'along',
#  114: 'plays',
#  115: 'stand',
#  116: 'looks',
#  117: 'building',
#  118: 'park',
#  119: 'climbing',
#  120: 'four',
#  121: 'top',
#  122: 'football',
#  123: 'face',
#  124: 'across',
#  125: 'grassy',
#  126: 'holds',
#  127: 'sand',
#  128: 'stick',
#  129: 'smiling',
#  130: 'ocean',
#  131: 'rides',
#  132: 'swimming',
#  133: 'hill',
#  134: 'skateboard',
#  135: 'carrying',
#  136: 'doing',
#  137: 'each',
#  138: 'tennis',
#  139: 'car',
#  140: 'snowy',
#  141: 'baby',
#  142: 'picture',
#  143: 'tree',
#  144: 'bicycle',
#  145: 'together',
#  146: 'hair',
#  147: 'him',
#  148: 's',
#  149: 'it',
#  150: 'jump',
#  151: 'area',
#  152: 'that',
#  153: 'basketball',
#  154: 'tan',
#  155: 'road',
#  156: 'trick',
#  157: 'race',
#  158: 'back',
#  159: 'head',
#  160: 'shorts',
#  161: 'bench',
#  162: 'sidewalk',
#  163: 'swing',
#  164: 'catch',
#  165: 'game',
#  166: 'run',
#  167: 'sit',
#  168: 'helmet',
#  169: 'ground',
#  170: 'dress',
#  171: 'something',
#  172: 'hand',
#  173: 'fence',
#  174: 'kids',
#  175: 'being',
#  176: 'frisbee',
#  177: 'lake',
#  178: 'path',
#  179: 'city',
#  180: 'ramp',
#  181: 'wave',
#  182: 'walk',
#  183: 'skateboarder',
#  184: 'several',
#  185: 'purple',
#  186: 'covered',
#  187: 'there',
#  188: 'side',
#  189: 'slide',
#  190: 'baseball',
#  191: 'posing',
#  192: 'track',
#  193: 'players',
#  194: 'wooden',
#  195: 'long',
#  196: 'high',
#  197: 'big',
#  198: 'sunglasses',
#  199: 'watches',
#  200: 'boat',
#  201: 'uniform',
#  202: 'coat',
#  203: 'trees',
#  204: 'them',
#  205: 'pants',
#  206: 'look',
#  207: 'table',
#  208: 'rocks',
#  209: 'ride',
#  210: 'watching',
#  211: 'motorcycle',
#  212: 'rope',
#  213: 'dark',
#  214: 'couple',
#  215: 'grey',
#  216: 'towards',
#  217: 'arms',
#  218: 'beside',
#  219: 'hands',
#  220: 'under',
#  221: 'rocky',
#  222: 'sign',
#  223: 'suit',
#  224: 'watch',
#  225: 'snowboarder',
#  226: 'river',
#  227: 'horse',
#  228: 'does',
#  229: 'above',
#  230: 'racing',
#  231: 'older',
#  232: 'jeans',
#  233: 'lady',
#  234: 'ice',
#  235: 'colorful',
#  236: 'striped',
#  237: 'pose',
#  238: 'who',
#  239: 'onto',
#  240: 'woods',
#  241: 'midair',
#  242: 'guy',
#  243: 'he',
#  244: 'glasses',
#  245: 'taking',
#  246: 'leaps',
#  247: 'mountains',
#  248: 'asian',
#  249: 'playground',
#  250: 'yard',
#  251: 'against',
#  252: 'climbs',
#  253: 'collar',
#  254: 'performing',
#  255: 'blonde',
#  256: 'cliff',
#  257: 'hockey',
#  258: 'cap',
#  259: 'bird',
#  260: 'smiles',
#  261: 'body',
#  262: 'blond',
#  263: 'open',
#  264: 'laying',
#  265: 'team',
#  266: 'surfer',
#  267: 'many',
#  268: 'rider',
#  269: 'after',
#  270: 'chasing',
#  271: 'kid',
#  272: 'fountain',
#  273: 'skier',
#  274: 'surrounded',
#  275: 'wet',
#  276: 'outdoors',
#  277: 'during',
#  278: 'inside',
#  279: 'flying',
#  280: 'old',
#  281: 'brick',
#  282: 'biker',
#  283: 'others',
#  284: 'shore',
#  285: 'edge',
#  286: 'takes',
#  287: 'colored',
#  288: 'away',
#  289: 'toddler',
#  290: 'guitar',
#  291: 'hanging',
#  292: 'trying',
#  293: 'very',
#  294: 'light',
#  295: 'someone',
#  296: 'forest',
#  297: 'backpack',
#  298: 'outfit',
#  299: 'middle',
#  300: 'night',
#  301: 'five',
#  302: 'pole',
#  303: 'bed',
#  304: 'talking',
#  305: 'object',
#  306: 'steps',
#  307: 'making',
#  308: 'nearby',
#  309: 'floor',
#  310: 'tshirt',
#  311: 'gray',
#  312: 'whilst',
#  313: 'about',
#  314: 'going',
#  315: 'flowers',
#  316: 'past',
#  317: 'line',
#  318: 'arm',
#  319: 'toward',
#  320: 'sky',
#  321: 'tall',
#  322: 'trail',
#  323: 'surfboard',
#  324: 'haired',
#  325: 'swinging',
#  326: 'eating',
#  327: 'dancing',
#  328: 'waves',
#  329: 'this',
#  330: 'poses',
#  331: 'bridge',
#  332: 'leaves',
#  333: 'board',
#  334: 'leaping',
#  335: 'day',
#  336: 'window',
#  337: 'all',
#  338: 'outdoor',
#  339: 'bag',
#  340: 'course',
#  341: 'clothes',
#  342: 'legs',
#  343: 'fighting',
#  344: 'room',
#  345: 'costume',
#  346: 'chair',
#  347: 'house',
#  348: 'leash',
#  349: 'plastic',
#  350: 'shallow',
#  351: 'clothing',
#  352: 'splashing',
#  353: 'carries',
#  354: 'stone',
#  355: 'ready',
#  356: 'between',
#  357: 'obstacle',
#  358: 'climber',
#  359: 'getting',
#  360: 'catches',
#  361: 'sliding',
#  362: 'bright',
#  363: 'adult',
#  364: 'they',
#  365: 'swings',
#  366: 'skateboarding',
#  367: 'waiting',
#  368: 'bathing',
#  369: 'sweater',
#  370: 'concrete',
#  371: 'shirts',
#  372: 'lawn',
#  373: 'trampoline',
#  374: 'sled',
#  375: 'wears',
#  376: 'skiing',
#  377: 'gear',
#  378: 'uniforms',
#  379: 'winter',
#  380: 'jersey',
#  381: 'mud',
#  382: 'metal',
#  383: 'male',
#  384: 'railing',
#  385: 'number',
#  386: 'sandy',
#  387: 'tongue',
#  388: 'stream',
#  389: 'store',
#  390: 'train',
#  391: 'fire',
#  392: 'pulling',
#  393: 'stairs',
#  394: 'catching',
#  395: 'throwing',
#  396: 'set',
#  397: 'distance',
#  398: 'lot',
#  399: 'golden',
#  400: 'drink',
#  401: 'get',
#  402: 'gets',
#  403: 'tries',
#  404: 'fishing',
#  405: 'bar',
#  406: 'adults',
#  407: 'sun',
#  408: 'shirtless',
#  409: 'overlooking',
#  410: 'swims',
#  411: 'flies',
#  412: 'smile',
#  413: 'rail',
#  414: 'female',
#  415: 'couch',
#  416: 'wooded',
#  417: 'tricks',
#  418: 'makes',
#  419: 'busy',
#  420: 'drinking',
#  421: 'puppy',
#  422: 'chases',
#  423: 'ski',
#  424: 'lying',
#  425: 'vest',
#  426: 'animal',
#  427: 'flag',
#  428: 'swim',
#  429: 'performs',
#  430: 'cellphone',
#  431: 'tire',
#  432: 'pond',
#  433: 'reading',
#  434: 'upside',
#  435: 'laughing',
#  436: 'surfing',
#  437: 'right',
#  438: 'trunks',
#  439: 'leaning',
#  440: 'shopping',
#  441: 'huge',
#  442: 'puddle',
#  443: 'dock',
#  444: 'she',
#  445: 'food',
#  446: 'slides',
#  447: 'horses',
#  448: 'eyes',
#  449: 'photo',
#  450: 'shoes',
#  451: 'flip',
#  452: 'sunset',
#  453: 'bat',
#  454: 'left',
#  455: 'nose',
#  456: 'hats',
#  457: 'kayak',
#  458: 'bubbles',
#  459: 'truck',
#  460: 'coming',
#  461: 'american',
#  462: 'snowboard',
#  463: 'hold',
#  464: 'scarf',
#  465: 'feet',
#  466: 'no',
#  467: 'or',
#  468: 'climb',
#  469: 'stunt',
#  470: 'life',
#  471: 'family',
#  472: 'cart',
#  473: 'bikes',
#  474: 'umbrella',
#  475: 'waterfall',
#  476: 'wetsuit',
#  477: 'elderly',
#  478: 'equipment',
#  479: 'restaurant',
#  480: 'view',
#  481: 'greyhound',
#  482: 'goal',
#  483: 'biting',
#  484: 'both',
#  485: 'hurdle',
#  486: 'lone',
#  487: 'tent',
#  488: 'harness',
#  489: 'deep',
#  490: 'skating',
#  491: 'skis',
#  492: 'setting',
#  493: 'bus',
#  494: 'mask',
#  495: 'muddy',
#  496: 'like',
#  497: 'take',
#  498: 'hiker',
#  499: 'falling',
#  500: 'flags',
#  501: 'vehicle',
#  502: 'dry',
#  503: 'paper',
#  504: 'skirt',
#  505: 'bags',
#  506: 'guys',
#  507: 'court',
#  508: 'surf',
#  509: 'sweatshirt',
#  510: 'closeup',
#  511: 'dresses',
#  512: 'structure',
#  513: 'ledge',
#  514: 'crowded',
#  515: 'fight',
#  516: 'book',
#  517: 'bmx',
#  518: 'six',
#  519: 'be',
#  520: 'tank',
#  521: 'pile',
#  522: 'slope',
#  523: 'cigarette',
#  524: 'raft',
#  525: 'airborne',
#  526: 'driving',
#  527: 'skate',
#  528: 'kick',
#  529: 'german',
#  530: 'have',
#  531: 'faces',
#  532: 'cement',
#  533: 'inflatable',
#  534: 'diving',
#  535: 'goggles',
#  536: 'subway',
#  537: 'costumes',
#  538: 'goes',
#  539: 'canoe',
#  540: 'parking',
#  541: 'teenage',
#  542: 'cyclist',
#  543: 'wood',
#  544: 'kicking',
#  545: 'bottle',
#  546: 'shaking',
#  547: 'splashes',
#  548: 'buildings',
#  549: 'dance',
#  550: 'fallen',
#  551: 'turn',
#  552: 'parade',
#  553: 'hit',
#  554: 'ears',
#  555: 'ring',
#  556: 'short',
#  557: 'shepherd',
#  558: 'jackets',
#  559: 'gathered',
#  560: 'blanket',
#  561: 'pictures',
#  562: 'backyard',
#  563: 'throws',
#  564: 'smaller',
#  565: 'tunnel',
#  566: 'band',
#  567: 'full',
#  568: 'silver',
#  569: 'sports',
#  570: 'chairs',
#  571: 'microphone',
#  572: 'smoking',
#  573: 'held',
#  574: 'sunny',
#  575: 'low',
#  576: 'bikini',
#  577: 'boots',
#  578: 'event',
#  579: 'balls',
#  580: 'beard',
#  581: 'leather',
#  582: 'surface',
#  583: 'cars',
#  584: 'cat',
#  585: 'fluffy',
#  586: 'graffiti',
#  587: 'stage',
#  588: 'kicks',
#  589: 'pushing',
#  590: 'using',
#  591: 'piece',
#  592: 'hiking',
#  593: 'outfits',
#  594: 'bull',
#  595: 'rugby',
#  596: 'painted',
#  597: 'statue',
#  598: 'bicyclist',
#  599: 'stuffed',
#  600: 'pointing',
#  601: 'box',
#  602: 'sticks',
#  603: 'steep',
#  604: 'bald',
#  605: 'bucket',
#  606: 'blowing',
#  607: 'paint',
#  608: 'glass',
#  609: 'tube',
#  610: 'door',
#  611: 'swimsuit',
#  612: 'wheel',
#  613: 'drinks',
#  614: 'suits',
#  615: 'sleeping',
#  616: 'scooter',
#  617: 'gold',
#  618: 'throw',
#  619: 'volleyball',
#  620: 'furry',
#  621: 'hugging',
#  622: 'corner',
#  623: 'wrestling',
#  624: 'cow',
#  625: 'net',
#  626: 'make',
#  627: 'crossing',
#  628: 'same',
#  629: 'flower',
#  630: 'hangs',
#  631: 'hind',
#  632: 'cowboy',
#  633: 'shot',
#  634: 'points',
#  635: 'leg',
#  636: 'motorcyclist',
#  637: 'staring',
#  638: 'leans',
#  639: 'attempting',
#  640: 'wrestle',
#  641: 'police',
#  642: 'kissing',
#  643: 'spectators',
#  644: 'lays',
#  645: 'sheep',
#  646: 'party',
#  647: 'attempts',
#  648: 'few',
#  649: 'teams',
#  650: 'show',
#  651: 'bunch',
#  652: 'log',
#  653: 'facing',
#  654: 'below',
#  655: 'wading',
#  656: 'beige',
#  657: 'bicycles',
#  658: 'puppies',
#  659: 'cup',
#  660: 'snowboarding',
#  661: 'garden',
#  662: 'desert',
#  663: 'sprinkler',
#  664: 'beautiful',
#  665: 'sticking',
#  666: 'underwater',
#  667: 'onlookers',
#  668: 'attached',
#  669: 'fish',
#  670: 'go',
#  671: 'softball',
#  672: 'gather',
#  673: 'competition',
#  674: 'eats',
#  675: 'fast',
#  676: 'waving',
#  677: 'end',
#  678: 'wide',
#  679: 'gym',
#  680: 'poles',
#  681: 'racket',
#  682: 'hoop',
#  683: 'racetrack',
#  684: 'which',
#  685: 'naked',
#  686: 'dances',
#  687: 'talks',
#  688: 'phone',
#  689: 'rain',
#  690: 'gravel',
#  691: 'base',
#  692: 'rolling',
#  693: 'way',
#  694: 'prepares',
#  695: 'seat',
#  696: 'empty',
#  697: 'motocross',
#  698: 'racer',
#  699: 'wings',
#  700: 'do',
#  701: 'headband',
#  702: 'signs',
#  703: 'platform',
#  704: 'snowcovered',
#  705: 'toys',
#  706: 'heads',
#  707: 'handstand',
#  708: 'cross',
#  709: 'hits',
#  710: 'clear',
#  711: 'ladies',
#  712: 'seated',
#  713: 'pushes',
#  714: 'plaid',
#  715: 'branch',
#  716: 'mohawk',
#  717: 'market',
#  718: 'downhill',
#  719: 'birds',
#  720: 'bride',
#  721: 'pavement',
#  722: 'paddling',
#  723: 'having',
#  724: 'public',
#  725: 'wear',
#  726: 'just',
#  727: 'shop',
#  728: 'neck',
#  729: 'fenced',
#  730: 'traffic',
#  731: 'rough',
#  732: 'scene',
#  733: 'among',
#  734: 'skateboards',
#  735: 'reads',
#  736: 'gloves',
#  737: 'chewing',
#  738: 'different',
#  739: 'beer',
#  740: 'hose',
#  741: 'thrown',
#  742: 'landscape',
#  743: 'rural',
#  744: 'drives',
#  745: 'barefoot',
#  746: 'urban',
#  747: 'kitchen',
#  748: 'teeth',
#  749: 'school',
#  750: 'races',
#  751: 'cream',
#  752: 'african',
#  753: 'balloon',
#  754: 'resting',
#  755: 'foot',
#  756: 'filled',
#  757: 'splash',
#  758: 'display',
#  759: 'shoulder',
#  760: 'dirty',
#  761: 'bars',
#  762: 'carnival',
#  763: 'before',
#  764: 'bottom',
#  765: 'cricket',
#  766: 'painting',
#  767: 'lies',
#  768: 'paved',
#  769: 'goalie',
#  770: 'wait',
#  771: 'lit',
#  772: 'indoor',
#  773: 'mother',
#  774: 'close',
#  775: 'plants',
#  776: 'carpet',
#  777: 'creek',
#  778: 'says',
#  779: 'waits',
#  780: 'younger',
#  781: 'bearded',
#  782: 'wedding',
#  783: 'smoke',
#  784: 'match',
#  785: 'opposing',
#  786: 'headphones',
#  787: 'animals',
#  788: 'lap',
#  789: 'fall',
#  790: 'showing',
#  791: 'rapids',
#  792: 'stadium',
#  793: 'greyhounds',
#  794: 'blows',
#  795: 'wrestler',
#  796: 'moving',
#  797: 'boats',
#  798: 'gun',
#  799: 'parked',
#  800: 'block',
#  801: 'reaching',
#  802: 'onstage',
#  803: 'skates',
#  804: 'santa',
#  805: 'seen',
#  806: 'paddle',
#  807: 'where',
#  808: 'mouths',
#  809: 'foreground',
#  810: 'talk',
#  811: 'chase',
#  812: 'tie',
#  813: 'bandanna',
#  814: 'third',
#  815: 'instruments',
#  816: 'singing',
#  817: 'lights',
#  818: 'runner',
#  819: 'falls',
#  820: 'hula',
#  821: 'can',
#  822: 'art',
#  823: 'deck',
#  824: 'atv',
#  825: 'helmets',
#  826: 'video',
#  827: 'pulled',
#  828: 'photograph',
#  829: 'ear',
#  830: 'motorbike',
#  831: 'funny',
#  832: 'matching',
#  833: 'poodle',
#  834: 'shooting',
#  835: 'ropes',
#  836: 'newspaper',
#  837: 'outstretched',
#  838: 'floating',
#  839: 'audience',
#  840: 'hitting',
#  841: 'fair',
#  842: 'try',
#  843: 'unicycle',
#  844: 'reaches',
#  845: 'pipe',
#  846: 'wire',
#  847: 'amusement',
#  848: 'multicolored',
#  849: 'hay',
#  850: 'staircase',
#  851: 'christmas',
#  852: 'spotted',
#  853: 'shakes',
#  854: 'duck',
#  855: 'hole',
#  856: 'fly',
#  857: 'atop',
#  858: 'spray',
#  859: 'bushes',
#  860: 'preparing',
#  861: 'bank',
#  862: 'alongside',
#  863: 'purse',
#  864: 'retriever',
#  865: 'pack',
#  866: 'martial',
#  867: 'shoulders',
#  868: 'curly',
#  869: 'wheelie',
#  870: 'raises',
#  871: 'bubble',
#  872: 'teenagers',
#  873: 'giant',
#  874: 'grinding',
#  875: 'flight',
#  876: 'appears',
#  877: 'lined',
#  878: 'skiers',
#  879: 'finger',
#  880: 'follows',
#  881: 'formation',
#  882: 'chain',
#  883: 'plate',
#  884: 'pulls',
#  885: 'kite',
#  886: 'digging',
#  887: 'larger',
#  888: 'surfs',
#  889: 'muzzle',
#  890: 'rowing',
#  891: 'putting',
#  892: 'terrain',
#  893: 'hikers',
#  894: 'alone',
#  895: 'station',
#  896: 'stop',
#  897: 'denim',
#  898: 'enjoys',
#  899: 'hoodie',
#  900: 'music',
#  901: 'balancing',
#  902: 'jeep',
#  903: 'covering',
#  904: 'perform',
#  905: 'muzzled',
#  906: 'rodeo',
#  907: 'row',
#  908: 'kneeling',
#  909: 'paddles',
#  910: 'puts',
#  911: 'giving',
#  912: 'shaggy',
#  913: 'picnic',
#  914: 'backwards',
#  915: 'gives',
#  916: 'indoors',
#  917: 'spinning',
#  918: 'himself',
#  919: 'parachute',
#  920: 'jumped',
#  921: 'break',
#  922: 'pier',
#  923: 'shows',
#  924: 'handrail',
#  925: 'laughs',
#  926: 'hooded',
#  927: 'bite',
#  928: 'cold',
#  929: 'roller',
#  930: 'backs',
#  931: 'shadow',
#  932: 'hang',
#  933: 'safety',
#  934: 'pull',
#  935: 'playfully',
#  936: 'clouds',
#  937: 'half',
#  938: 'backpacks',
#  939: 'brightly',
#  940: 'makeup',
#  941: 'writing',
#  942: 'ladder',
#  943: 'enjoying',
#  944: 'owner',
#  945: 'competing',
#  946: 'necklace',
#  947: 'gate',
#  948: 'counter',
#  949: 'sniffing',
#  950: 'licking',
#  951: 'riders',
#  952: 'round',
#  953: 'terrier',
#  954: 'seven',
#  955: 'bites',
#  956: 'construction',
#  957: 'machine',
#  958: 'fetch',
#  959: 'bikers',
#  960: 'underneath',
#  961: 'cloth',
#  962: 'mound',
#  963: 'basket',
#  964: 'violin',
#  965: 'doorway',
#  966: 'fingers',
#  967: 'passing',
#  968: 'tackle',
#  969: 'bowl',
#  970: 'rink',
#  971: 'crouches',
#  972: 'quickly',
#  973: 'paws',
#  974: 'sea',
#  975: 'collie',
#  976: 'tug',
#  977: 'step',
#  978: 'leap',
#  979: 'computer',
#  980: 'camouflage',
#  981: 'these',
#  982: 'splashed',
#  983: 'jungle',
#  984: 'hillside',
#  985: 'referee',
#  986: 'taken',
#  987: 'made',
#  988: 'fur',
#  989: 'coats',
#  990: 'professional',
#  991: 'rollerblades',
#  992: 'decorated',
#  993: 'friend',
#  994: 'pigeons',
#  995: 'ducks',
#  996: 'wheelchair',
#  997: 'spots',
#  998: 'waters',
#  999: 'kayaking',
#  1000: 'helps',
#  ...}

# %%
#Saving Caption file
file = "../raw_data/captions/cap"
outfile = open(file,'wb')
dump(f,outfile)
outfile.close()

# %%
file = "../raw_data/captions/cap"

# %%
with open(file, 'rb') as handle:
    b = load(handle)
